# %%
import paddle

# %%
paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 CPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.
# I0121 18:25:38.676312 1322698368 program_interpreter.cc:212] New Executor is Running.
# I0121 18:25:38.717695 1322698368 interpreter_util.cc:624] Standalone Executor is Used.

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(lang='korean')

img_path = 'test2.png'

result = ocr.ocr(img_path, cls=False)

ocr_reuslt = result[0]

print(ocr_reuslt)
# Out:
# [2024/01/21 18:25:44] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/kimsy/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/kimsy/.paddleocr/whl/rec/korean/korean_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_te
# ...

# %%
from paddleocr import PaddleOCR
ocr = PaddleOCR(lang='korean')

img_path = 'test_sample.png'
result = ocr.ocr(img_path, cls=True)

ocr_reuslt = result[0]
# Out:
# [2024/01/18 23:35:21] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/kimsy/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/kimsy/.paddleocr/whl/rec/korean/korean_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_te
# ...

# %%
result[0][1][1]
# Out:
# ('1제품명', 0.9971380829811096)

# %%
ocr_reuslt[1][1]
# Out:
# ('1제품명', 0.9971380829811096)

# %%
dump = []
for res in ocr_reuslt:
    dump.append(res[1])
    
dump
# Out:
# [('한글표시사항', 0.999673068523407),
#  ('1제품명', 0.9971380829811096),
#  (':냉동소족', 0.9988303184509277),
#  ('식육의종류및부위명', 0.9909756183624268),
#  ('수입쇠고기부산물소족', 0.9990566968917847),
#  ('3', 0.9999988079071045),
#  ('영업자의', 0.9975249767303467),
#  ('명칭상호', 0.9935739040374756),
#  ('주식회사이노미트', 0.9984871745109558),
#  ('경기도', 0.9998071789741516),
#  ('성남시수정구위례서일로', 0.9993484616279602),
#  ('30 2층', 0.9960027933120728),
#  ('205호', 0.9998644590377808),
#  ('창', 0.7595170736312866),
#  ('위례헤라', 0.9420261383056641),
#  ('031:753-7782', 0.9913976192474365),
#  ('1제:', 0.7228013873100281),
#  (':월/일/년', 0.9237327575683594),
#  ('미:', 0.5422458648681641),
#  ('H-', 0.6580257415771484),
#  ('APR-4울', 0.8274170756340027),
#  ("'OG]", 0.6899374723434448),
#  ('HNOv-월DEc-2월', 0.7449009418487549),
#  ('독면에', 0.9134547114372253),
#  ('별도표기단위:Kg', 0.9840958714485168),
#  ('소족100%', 0.9984689354896545),
#  ('이하냉동보관', 0.9995356202125549),
#  ('쇠고기함유', 0.9958488345146179),
#  ('18C', 0.8961417078971863),
# ...

# %%
import pandas as pd
df = pd.DataFrame(dump, columns=['words', 'recognition_p'])
df.head()
# Out:
#         words  recognition_p
# 0      한글표시사항       0.999673
# 1        1제품명       0.997138
# 2       :냉동소족       0.998830
# 3   식육의종류및부위명       0.990976
# 4  수입쇠고기부산물소족       0.999057

# %%
df[df['recognition_p']<0.6]
# Out:
#    words  recognition_p
# 18    미:       0.542246

# %%
df['recognition_p'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['recognition_p']<0.8]
# Out:
#            words  recognition_p
# 13             창       0.759517
# 16           1제:       0.722801
# 18            미:       0.542246
# 19            H-       0.658026
# 21          'OG]       0.689937
# 22  HNOv-월DEc-2월       0.744901
# 35  해동용동국거리및필구이등       0.795625

# %%
df
# Out:
#                    words  recognition_p
# 0                 한글표시사항       0.999673
# 1                   1제품명       0.997138
# 2                  :냉동소족       0.998830
# 3              식육의종류및부위명       0.990976
# 4             수입쇠고기부산물소족       0.999057
# 5                      3       0.999999
# 6                   영업자의       0.997525
# 7                   명칭상호       0.993574
# 8               주식회사이노미트       0.998487
# 9                    경기도       0.999807
# 10           성남시수정구위례서일로       0.999348
# 11                 30 2층       0.996003
# 12                  205호       0.999864
# 13                     창       0.759517
# 14                  위례헤라       0.942026
# 15          031:753-7782       0.991398
# 16                   1제:       0.722801
# 17                :월/일/년       0.923733
# 18                    미:       0.542246
# 19                    H-       0.658026
# 20                APR-4울       0.827417
# 21                  'OG]       0.689937
# ...

# %%
from paddleocr import PaddleOCR
ocr = PaddleOCR(

                lang='korean',

                )

img_path = 'test_sample_3.jpeg'
result = ocr.ocr(img_path, cls=True)

ocr_reuslt = result[0]

dump = []
for res in ocr_reuslt:
    dump.append(res[1])
    
df = pd.DataFrame(dump, columns=['words', 'recognition_p'])
df.head()
# Out:
# [2024/01/19 00:10:44] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/kimsy/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/kimsy/.paddleocr/whl/rec/korean/korean_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_te
# ...

# %%
df['recognition_p'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head(30)
# Out:
#                              words  recognition_p
# 0                              제품명       0.970868
# 1                              뿌리원       0.997527
# 2                           통치자단무지       0.999758
# 3                            식품의유형       0.999723
# 4                             절임식품       0.997401
# 5                           농업회사법인       0.999117
# 6                          정스팜주/T터       0.897614
# 7                      031875-3861       0.966441
# 8                              제조'       0.780314
# 9                              경기도       0.999852
# 10                             양주시       0.999595
# 11                             백석읍       0.999572
# 12                             권율로       0.999273
# 13                          1203번길       0.998607
# 14                            8-35       0.902384
# 15                          품질유지기한       0.999816
# 16                              전면       0.999546
# 17                         별도표시일까지       0.999861
# ...

# %%
'''ocr = PaddleOCR(use_gpu=False, # GPU 사용 설정
                lang='en', # 언어 설정
                det_model_dir='path/to/det_model', # 검출 모델 경로
                rec_model_dir='path/to/rec_model', # 인식 모델 경로
                det_threshold=0.5, # 검출 임계값
                rec_char_type='en', # 인식할 문자 유형
                rec_char_dict_path='path/to/dict', # 문자 집합 파일 경로
                max_text_length=25, # 최대 문자 길이
                cls_model_dir='path/to/cls_model', # 언어 분류 모델 경로
                enable_mkldnn=True, # MKL-DNN 사용 설정
                use_angle_cls=True) # 문자 방향 조정 사용 설정'''

# %% [markdown]
# ## 추가 파라미터 적용

# %%
from paddleocr import PaddleOCR
ocr = PaddleOCR(

                lang='korean',

                )

img_path = 'test_sample_3.jpeg'
result = ocr.ocr(img_path, cls=True)

ocr_reuslt = result[0]

dump = []
for res in ocr_reuslt:
    dump.append(res[1])
    
df = pd.DataFrame(dump, columns=['words', 'recognition_p'])
df.head()

# %%
from paddleocr import PaddleOCR, draw_ocr
import matplotlib.pyplot as plt
from PIL import Image

# PaddleOCR 인스턴스 생성
ocr = PaddleOCR(use_angle_cls=True, lang='korean') # use_angle_cls는 틀어진 이미지를 자동으로 조정, lang='ko'로 한글 인식 설정

# 인식할 이미지 파일 경로
image_path = 'test_sample_3.jpeg'

# OCR 실행
result = ocr.ocr(image_path, cls=True)

# 인식된 결과 출력 및 시각화
image = Image.open(image_path).convert('RGB')
boxes = [line[0] for line in result]
txts = [line[1][0] for line in result]
scores = [line[1][1] for line in result]

# 이미지에 결과 그리기
im_show = draw_ocr(image, boxes, txts, scores, font_path='/Users/kimsy/Library/Fonts/D2Coding-Ver1.3.2-20180524-all.ttc')
im_show = Image.fromarray(im_show)

# 결과 이미지 표시
plt.imshow(im_show)
plt.show()

# 인식된 텍스트 출력
for line in result:
    print(line)
# Out:
# [2024/01/21 18:37:57] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/kimsy/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/kimsy/.paddleocr/whl/rec/korean/korean_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_te
# ...

# %%
from paddleocr import PaddleOCR, draw_ocr
import matplotlib.pyplot as plt
from PIL import Image

# PaddleOCR 인스턴스 생성
ocr = PaddleOCR(use_angle_cls=True, lang='korean') # use_angle_cls는 틀어진 이미지를 자동으로 조정, lang='ko'로 한글 인식 설정

# 인식할 이미지 파일 경로
image_path = 'test_sample_3.jpeg'

# OCR 실행
result = ocr.ocr(image_path, cls=True)

# 인식된 결과 출력 및 시각화
image = Image.open(image_path).convert('RGB')
boxes = [line[0] for line in result]
txts = [line[1][0] for line in result]

# scores 변수의 값을 float로 변환
scores = [float(line[1][1]) for line in result]

# 이미지에 결과 그리기
im_show = draw_ocr(image, boxes, txts, scores, font_path='/Users/kimsy/Library/Fonts/D2Coding-Ver1.3.2-20180524-all.ttc')
im_show = Image.fromarray(im_show)

# 결과 이미지 표시
plt.imshow(im_show)
plt.show()

# 인식된 텍스트 출력
for line in result:
    print(line)
# Out:
# [2024/01/21 18:42:37] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/kimsy/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/kimsy/.paddleocr/whl/rec/korean/korean_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_te
# ...
